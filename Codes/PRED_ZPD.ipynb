# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
from scipy.stats import skellam
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Data of 2009-2010
Pred_Data=pd.read_csv("../Data/2009-2010.csv")
Pred_Data=Pred_Data[['HomeTeam','AwayTeam','FTHG','FTAG','FTR']]
Pred_Data.columns=['Home','Away','HG','AG','Result']
Team=Pred_Data.Home.value_counts().index
Pred_Data['diff_score']=Pred_Data['HG']-Pred_Data['AG']

# %% [markdown]
# # Useful function for our predictions

# %%
#Calculate the means
def score_coef(att,dif,delta,Data):
    mu1=np.array([])
    mu2=np.array([])
    for i in range(len(Pred_Data)):
        m1=np.exp(delta+att.loc[Data.loc[i].Home]-dif.loc[Data.loc[i].Away])
        m2=np.exp(att.loc[Data.loc[i].Away]-dif.loc[Data.loc[i].Home])
        mu1=np.append(mu1,m1)
        mu2=np.append(mu2,m2)
    return mu1, mu2

# %%
#Predict the result using the new prediction for the Draw
def prediction(p,lamb1,lamb2):
    a=np.random.rand()
    if a<p:
        return 0
    else : return int(np.mean(skellam.rvs(lamb1,lamb2,1)))

# %%
#Function to calculate the mean for a given match
def calc_score(att_h,dif_h,att_a,dif_a,delta):
    m1=np.exp(delta+att_h-dif_a)
    m2=np.exp(att_a-dif_h)
    return m1, m2

# %%
#Define the probability of winning against an other team without home coef.
def probawin(A,B,k=0):
    mu_h,mu_a=calc_score(A[0],A[1],B[0],B[1],delta=0)
    return 1-skellam.cdf(k,  mu_h,  mu_a)

# %% [markdown]
# # Prediction Using Metropolis within Gibbs results

# %%
Coef_club=pd.read_csv('../Data/Coef_MCMC_ZPD.csv')
Coef_club=Coef_club.set_index('Team').sort_index()
Team=Pred_Data.Home.value_counts().index
delta=Coef_club['Home_adv'][0]
p=Coef_club['prob'][0]
classement_mean=pd.DataFrame({'Team':Team})

# %%
Sum_Coef_club= Coef_club[['Sum_Att','Sum_Dif']]
Sum_Coef_club
# Out:
#              Sum_Att   Sum_Dif
# Team
# Atalanta   -0.027717 -0.131890
# Bari        0.247040 -0.048888
# Bologna     0.006414 -0.303488
# Cagliari   -0.313895  0.120504
# Catania    -0.209007 -0.019794
# Chievo     -0.176559 -0.020045
# Fiorentina  0.300688 -0.157895
# Genoa      -0.083507  0.039322
# Inter       0.130735  0.918435
# Juventus    0.341535 -0.015780
# Lazio       0.168722 -0.233277
# Livorno    -0.214874 -0.390478
# Milan       0.258111  0.123700
# Napoli     -0.080961  0.133878
# Palermo     0.079661 -0.054089
# Parma      -0.469853 -0.024351
# Roma        0.234590  0.313575
# Sampdoria   0.062872 -0.122433
# Siena      -0.266375 -0.128321
# Udinese     0.012620  0.000963

# %%
#Generate the means of the Home and Away teams 
mu1 ,mu2=score_coef(Coef_club['Sum_Att'],Coef_club['Sum_Dif'],delta,Pred_Data)

# %%
totdif= list()
#Create 1000 different new result
for i in range(1):
    dif_pred = "iter"+str(i)
    pred=[]
    for j in range(len(Pred_Data)):
        pred=np.concatenate([pred,[prediction(p,mu1[j],mu2[j])]])  
    Pred_Data[dif_pred]=pred
    totdif.append(dif_pred)

avg_dif=0
for i in totdif:
    avg_dif+=Pred_Data[i]
avg_dif=avg_dif/len(totdif)
Pred_Data['New_pred_diff_score']=avg_dif

#Predict the result averaging the 1000 simulation
pred_result=np.array([])
for i in range (len(Pred_Data)):
    if Pred_Data.iloc[i]['New_pred_diff_score']>0.25:
        pred_result=np.concatenate([pred_result,['H']])
    elif Pred_Data.iloc[i]['New_pred_diff_score']<0:
        pred_result=np.concatenate([pred_result,['A']])
    else : pred_result=np.concatenate([pred_result,['D']])
Pred_Data['New_pred_result']=pred_result

# %%
#Count the number of match mispredicted
diff_score=np.array([])
wrong_res=0
for i in range(379):
    if Pred_Data['Result'][i]==Pred_Data['New_pred_result'][i]:
        diff_score=np.append(diff_score,0)
    else:
        diff_score=np.append(diff_score,1)
        wrong_res+=1

(380-wrong_res)/380
# Out:
# 0.48947368421052634

# %%
Score=np.array([])
for i in Team :
    s=0
    dom=Pred_Data[Pred_Data.Home==i]
    ext=Pred_Data[Pred_Data.Away==i]
    for j in range(len(dom)):
        if dom.iloc[j]['New_pred_result']=='H':
                s+=3
        elif dom.iloc[j]['New_pred_result']=='D':
                s+=1
    for j in range(len(ext)):
        if ext.iloc[j]['New_pred_result']=='A':
                s+=3
        elif ext.iloc[j]['New_pred_result']=='D':
                s+=1   
    Score=np.concatenate([Score,[s]])
classement_mean['Classifica']=Score
#classement=classement.set_index('Team')
classement_mean.sort_values(by='Classifica',ascending=False)
# Out:
#           Team  Classifica
# 16       Inter        71.0
# 6         Roma        69.0
# 0        Milan        63.0
# 11        Bari        63.0
# 4      Udinese        62.0
# 17       Lazio        61.0
# 13      Napoli        60.0
# 5   Fiorentina        54.0
# 7     Juventus        54.0
# 8     Cagliari        54.0
# 10     Palermo        53.0
# 9    Sampdoria        50.0
# 19     Catania        50.0
# 2        Genoa        49.0
# 14     Livorno        47.0
# 15     Bologna        47.0
# 1        Siena        42.0
# 3       Chievo        42.0
# 12    Atalanta        41.0
# 18       Parma        40.0

# %%
#Create a table containing all the probabilities 
proba_tot=[]
for i in range(len(Sum_Coef_club)):
    A=Sum_Coef_club.iloc[i]
    proba_A=[]
    for j in range(len(Sum_Coef_club)):
        if j !=i:
            B=Sum_Coef_club.iloc[j]
            proba_A.append(probawin(A,B))
        if j==i:
            proba_A.append(0)
    proba_tot.append(proba_A)

# %%
prob=pd.DataFrame({'Team':Team})
prob=prob.set_index('Team').sort_index()
ordered=Team.sort_values()
j=0
for i in ordered:
    prob[i]=np.transpose(proba_tot)[j]
    j+=1

# %%
prob.style.background_gradient(
    cmap = sns.palettes.diverging_palette(h_neg=0, h_pos=243, s=75, l=40,
                                          as_cmap=True))
# Out:
# <style  type="text/css" >
#     #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col0 {
#             background-color:  #ab2f53;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col1 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col2 {
#             background-color:  #cad7e3;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col3 {
#             background-color:  #c2d2df;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col4 {
#             background-color:  #c5d4e1;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col5 {
#             background-color:  #c8d6e2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col6 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col7 {
#             background-color:  #d6e1eb;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col8 {
#             background-color:  #eaf0f6;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col9 {
#             background-color:  #f7e5ea;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col10 {
#             background-color:  #e1eaf1;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col11 {
#             background-color:  #acc1d2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col12 {
#             background-color:  #f8e7ec;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col13 {
#             background-color:  #dae5ed;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col14 {
#             background-color:  #e2ebf2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col15 {
#             background-color:  #aec2d3;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col16 {
#             background-color:  #f5e1e7;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col17 {
#             background-color:  #dce6ee;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col18 {
#             background-color:  #b9cad9;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row0_col19 {
#             background-color:  #dee7ef;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col0 {
#             background-color:  #85a2bb;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col1 {
#             background-color:  #ab2f53;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col2 {
#             background-color:  #7d9cb6;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col3 {
#             background-color:  #7696b1;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col4 {
#             background-color:  #7998b3;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col5 {
#             background-color:  #7c9bb5;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col6 {
#             background-color:  #a8bdcf;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col7 {
#             background-color:  #88a4bc;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col8 {
#             background-color:  #8faac1;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col9 {
#             background-color:  #b6c8d8;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col10 {
#             background-color:  #93adc3;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col11 {
#             background-color:  #678aa8;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col12 {
#             background-color:  #b4c7d7;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col13 {
#             background-color:  #8ca8bf;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col14 {
#             background-color:  #94aec4;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col15 {
#             background-color:  #6589a8;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col16 {
#             background-color:  #bccddb;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col17 {
#             background-color:  #8ea9c0;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col18 {
#             background-color:  #6f91ae;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row1_col19 {
#             background-color:  #8faac1;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col0 {
#             background-color:  #e5edf4;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col1 {
#             background-color:  #f2d9e0;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col2 {
#             background-color:  #ab2f53;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col3 {
#             background-color:  #d4e0ea;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col4 {
#             background-color:  #d7e2ec;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col5 {
#             background-color:  #dae5ed;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col6 {
#             background-color:  #f2dae1;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col7 {
#             background-color:  #eaf0f6;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col8 {
#             background-color:  #f5dfe5;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col9 {
#             background-color:  #ebc9d3;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col10 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col11 {
#             background-color:  #bccddb;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col12 {
#             background-color:  #edced7;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col13 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col14 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col15 {
#             background-color:  #bccddb;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col16 {
#             background-color:  #eac6d1;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col17 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col18 {
#             background-color:  #cad7e3;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row2_col19 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col0 {
#             background-color:  #e7eef5;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col1 {
#             background-color:  #f8e7ec;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col2 {
#             background-color:  #dfe9f0;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col3 {
#             background-color:  #ab2f53;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col4 {
#             background-color:  #dfe9f0;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col5 {
#             background-color:  #e2ebf2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col6 {
#             background-color:  #f8e7ec;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col7 {
#             background-color:  #ebf2f7;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col8 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col9 {
#             background-color:  #f3dce3;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col10 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col11 {
#             background-color:  #cad7e3;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col12 {
#             background-color:  #f4dee4;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col13 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col14 {
#             background-color:  #f2f2f2;
#         }    #T_d1c61710_90d2_11e9_ad86_34e12d888ef6row3_col15 {
#             background-color:  #cfdbe6;
#         }    #T_d1c61710_90d2_11e9_ad86_34e

# %%
Pred_Data['Result'].value_counts()
# Out:
# H    186
# D    102
# A     92
# Name: Result, dtype: int64

# %%
Pred_Data['New_pred_result'].value_counts()
# Out:
# H    276
# D     68
# A     36
# Name: New_pred_result, dtype: int64

# %%
p
# Out:
# 0.006876549776571544

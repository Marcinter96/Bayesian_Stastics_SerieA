# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import skellam
import seaborn as sns
# %matplotlib inline

# %%
Pred_Data=pd.read_csv("../Data/2009-2010.csv")
Pred_Data=Pred_Data[['HomeTeam','AwayTeam','FTHG','FTAG','FTR']]
Pred_Data.columns=['Home','Away','HG','AG','Result']
Team=Pred_Data.Home.value_counts().index

# %%
len(Pred_Data[Pred_Data['Result']=='H'])/len(Pred_Data)
# Out:
# 0.48947368421052634

# %% [markdown]
# # Useful function for our predictions

# %%
#Function to calculate the mean for all the Data
def score_coef(att,dif,delta,Data):
    mu1=np.array([])
    mu2=np.array([])
    for i in range(len(Pred_Data)):
        m1=np.exp(delta+att.loc[Data.loc[i].Home]-dif.loc[Data.loc[i].Away])
        m2=np.exp(att.loc[Data.loc[i].Away]-dif.loc[Data.loc[i].Home])
        mu1=np.append(mu1,m1)
        mu2=np.append(mu2,m2)
    return mu1, mu2

# %%
#Function to calculate the mean for a given match
def calc_score(att_h,dif_h,att_a,dif_a):
    m1=np.exp(att_h-dif_a)
    m2=np.exp(att_a-dif_h)
    return m1, m2

# %%
#Calculate the probability of winning against another team without home coef
def probawin(A,B,k=0):
    mu_h,mu_a=calc_score(A[0],A[1],B[0],B[1])
    return 1-skellam.cdf(k,  mu_h,  mu_a)

# %% [markdown]
# # Prediction Using Metropolis within Gibbs results

# %%
#Get the results obtained with our MCMC
Coef_club=pd.read_csv('../Data/Coef_MCMC_Poiss.csv')
Coef_club=Coef_club.set_index('Team').sort_index()
Team=Pred_Data.Home.value_counts().index
delta=Coef_club['Home_adv'][0]
classement_mean=pd.DataFrame({'Team':Team})

# %%
Sum_Coef_club=Coef_club[['Sum_Att','Sum_Dif']]
Sum_Coef_club
# Out:
#              Sum_Att   Sum_Dif
# Team
# Atalanta   -0.024221 -0.075977
# Bari       -0.046574  0.028818
# Bologna    -0.206872 -0.142026
# Cagliari   -0.006719 -0.069770
# Catania    -0.192182 -0.017661
# Chievo     -0.290591  0.079018
# Fiorentina  0.035820  0.153798
# Genoa       0.040527 -0.067544
# Inter       0.406135  0.310904
# Juventus    0.290654  0.070085
# Lazio      -0.063812  0.029220
# Livorno    -0.381195 -0.227413
# Milan       0.239456  0.226186
# Napoli     -0.000267  0.027827
# Palermo     0.158019 -0.056332
# Parma      -0.171354 -0.164231
# Roma        0.354805  0.105756
# Sampdoria   0.000848  0.003786
# Siena      -0.244061 -0.060085
# Udinese     0.101614 -0.154383

# %%
#Generate the means for our Poisson
mu1, mu2=score_coef(Coef_club['Sum_Att'],Coef_club['Sum_Dif'],delta,Pred_Data)

# %%
#Results for one simulation of Poisson with our means mu1 and mu2
Pred_Data['predH']=np.random.poisson(mu1)
Pred_Data['predA']=np.random.poisson(mu2)

pred_result=np.array([])
for i in range (len(Pred_Data)):
    if Pred_Data.iloc[i]['predH']>Pred_Data.iloc[i]['predA']:
        pred_result=np.concatenate([pred_result,['H']])
    elif Pred_Data.iloc[i]['predH']<Pred_Data.iloc[i]['predA']:
        pred_result=np.concatenate([pred_result,['A']])
    else : pred_result=np.concatenate([pred_result,['D']])
Pred_Data['pred_result']=pred_result
#Count the number of mispredicted matches
diff_score=np.array([])
wrong_res=0
for i in range(379):
    if Pred_Data['Result'][i]==Pred_Data['pred_result'][i]:
        diff_score=np.append(diff_score,0)
    else:
        diff_score=np.append(diff_score,1)
        wrong_res+=1

(380-wrong_res)/380
# Out:
# 0.4342105263157895

# %%
#Generate 1000 simulations of Poisson distribution
totpredH= list()
totpredA= list()
for i in range(1000):
    home_pred = "iter"+str(i)+"home"
    away_pred = "iter"+str(i)+"away"
    Pred_Data[home_pred]=np.random.poisson(mu1)
    Pred_Data[away_pred]=np.random.poisson(mu2)
    totpredH.append(home_pred)
    totpredA.append(away_pred)

# %%
#Take the mean of the sum of the goals for each simulations
avg_home=0
avg_away=0
for i in totpredH:
    avg_home+=Pred_Data[i]
avg_home=avg_home/len(totpredH)

for j in totpredA:
    avg_away+=Pred_Data[j]
avg_away=avg_away/len(totpredA)

# %%
home_goal=(avg_home)
away_goal=(avg_away)
Pred_Data['New_HG']=home_goal
Pred_Data['New_AG']=away_goal

# %%
#Create a column with the results
pred_result=np.array([])
for i in range (len(Pred_Data)):
    if Pred_Data.iloc[i]['New_HG']-Pred_Data.iloc[i]['New_AG']>0.25:
        pred_result=np.concatenate([pred_result,['H']])
    elif Pred_Data.iloc[i]['New_HG']-Pred_Data.iloc[i]['New_AG']<0.:
        pred_result=np.concatenate([pred_result,['A']])
    else : pred_result=np.concatenate([pred_result,['D']])
Pred_Data['New_pred_result']=pred_result

# %%
#Count the number of mispredicted results
diff_score=np.array([])
wrong_res=0
for i in range(379):
    if Pred_Data['Result'][i]==Pred_Data['New_pred_result'][i]:
        diff_score=np.append(diff_score,0)
    else:
        diff_score=np.append(diff_score,1)
        wrong_res+=1

(380-wrong_res)/380
# Out:
# 0.5026315789473684

# %%
#Create a Ranking with the new results obtained
Score=np.array([])
for i in Team :
    s=0
    dom=Pred_Data[Pred_Data.Home==i]
    ext=Pred_Data[Pred_Data.Away==i]
    for j in range(len(dom)):
        if dom.iloc[j]['New_pred_result']=='H':
                s+=3
        elif dom.iloc[j]['New_pred_result']=='D':
                s+=1
    for j in range(len(ext)):
        if ext.iloc[j]['New_pred_result']=='A':
                s+=3
        elif ext.iloc[j]['New_pred_result']=='D':
                s+=1   
    Score=np.concatenate([Score,[s]])
classement_mean['Classifica']=Score
#classement=classement.set_index('Team')
classement_mean.sort_values(by='Classifica',ascending=False)
# Out:
#           Team  Classifica
# 10       Inter       110.0
# 9        Milan       101.0
# 11        Roma        99.0
# 14    Juventus        89.0
# 15  Fiorentina        76.0
# 4      Palermo        63.0
# 7       Napoli        52.0
# 1         Bari        52.0
# 18   Sampdoria        51.0
# 5        Genoa        51.0
# 16     Udinese        51.0
# 2        Lazio        50.0
# 17    Cagliari        50.0
# 13    Atalanta        50.0
# 19     Catania        35.0
# 3       Chievo        28.0
# 12       Siena        24.0
# 8      Bologna        24.0
# 6        Parma        24.0
# 0      Livorno         3.0

# %% [markdown]
# We have that our ranking is consistent with the real results but does not give much information on the number of well predicted results

# %%
prob=pd.DataFrame({'Team':Team})
prob=prob.set_index('Team').sort_index()

# %%
#Create Matrix containing all the probabilities
proba_tot=[]
for i in range(len(Sum_Coef_club)):
    A=Sum_Coef_club.iloc[i]
    proba_A=[]
    for j in range(len(Sum_Coef_club)):
        if j !=i:
            B=Sum_Coef_club.iloc[j]
            proba_A.append(probawin(A,B))
        if j==i:
            proba_A.append(0)
    proba_tot.append(proba_A)

# %%
XA=Team.sort_values()
j=0
for i in XA:
    prob[i]=np.transpose(proba_tot)[j]
    j+=1

# %%
prob.style.background_gradient(
    cmap = sns.palettes.diverging_palette(h_neg=0, h_pos=243, s=75, l=40,
                                          as_cmap=True))
# Out:
# <style  type="text/css" >
#     #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col0 {
#             background-color:  #ab2f53;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col1 {
#             background-color:  #d4e0ea;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col2 {
#             background-color:  #c1d1de;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col3 {
#             background-color:  #d3dfe9;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col4 {
#             background-color:  #c8d6e2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col5 {
#             background-color:  #c7d5e2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col6 {
#             background-color:  #e1eaf1;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col7 {
#             background-color:  #d6e1eb;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col8 {
#             background-color:  #dce6ee;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col9 {
#             background-color:  #f2f2f2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col10 {
#             background-color:  #d3dfe9;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col11 {
#             background-color:  #b2c5d5;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col12 {
#             background-color:  #f2f2f2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col13 {
#             background-color:  #d7e2ec;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col14 {
#             background-color:  #e1eaf1;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col15 {
#             background-color:  #c2d2df;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col16 {
#             background-color:  #f2f2f2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col17 {
#             background-color:  #d6e1eb;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col18 {
#             background-color:  #c2d2df;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row0_col19 {
#             background-color:  #d6e1eb;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col0 {
#             background-color:  #c7d5e2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col1 {
#             background-color:  #ab2f53;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col2 {
#             background-color:  #b9cad9;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col3 {
#             background-color:  #c8d6e2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col4 {
#             background-color:  #bfd0dd;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col5 {
#             background-color:  #bfd0dd;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col6 {
#             background-color:  #d4e0ea;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col7 {
#             background-color:  #cbd9e4;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col8 {
#             background-color:  #c7d5e2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col9 {
#             background-color:  #e2ebf2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col10 {
#             background-color:  #c8d6e2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col11 {
#             background-color:  #abc0d1;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col12 {
#             background-color:  #e4ecf3;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col13 {
#             background-color:  #ccdae5;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col14 {
#             background-color:  #d3dfe9;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col15 {
#             background-color:  #b9cad9;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col16 {
#             background-color:  #e8eff5;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col17 {
#             background-color:  #cbd9e4;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col18 {
#             background-color:  #baccda;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row1_col19 {
#             background-color:  #cbd9e4;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col0 {
#             background-color:  #faebef;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col1 {
#             background-color:  #f8e8ed;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col2 {
#             background-color:  #ab2f53;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col3 {
#             background-color:  #f9eaee;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col4 {
#             background-color:  #f2f2f2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col5 {
#             background-color:  #f2f2f2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col6 {
#             background-color:  #f3dce3;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col7 {
#             background-color:  #f7e5ea;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col8 {
#             background-color:  #f1d6de;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col9 {
#             background-color:  #ebc9d3;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col10 {
#             background-color:  #f9eaee;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col11 {
#             background-color:  #dce6ee;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col12 {
#             background-color:  #ebc9d3;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col13 {
#             background-color:  #f7e5ea;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col14 {
#             background-color:  #f3dce3;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col15 {
#             background-color:  #ecf3f8;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col16 {
#             background-color:  #e9c3ce;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col17 {
#             background-color:  #f7e5ea;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col18 {
#             background-color:  #f2f2f2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row2_col19 {
#             background-color:  #f7e5ea;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col0 {
#             background-color:  #ccdae5;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col1 {
#             background-color:  #d0dde7;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col2 {
#             background-color:  #bccddb;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col3 {
#             background-color:  #ab2f53;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col4 {
#             background-color:  #c4d3e0;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col5 {
#             background-color:  #c2d2df;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col6 {
#             background-color:  #dce6ee;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col7 {
#             background-color:  #d2dee8;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col8 {
#             background-color:  #d7e2ec;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col9 {
#             background-color:  #ecf3f8;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col10 {
#             background-color:  #cfdbe6;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col11 {
#             background-color:  #acc1d2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col12 {
#             background-color:  #f2f2f2;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col13 {
#             background-color:  #d3dfe9;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col14 {
#             background-color:  #dce6ee;
#         }    #T_42d11fca_90fb_11e9_8756_34e12d888ef6row3_col15 {
#             background-color:  #bdcedc;
#         }    #T_42d11fca_90fb_11e9_8756_34e

# %%
Pred_Data['Result'].value_counts()
# Out:
# H    186
# D    102
# A     92
# Name: Result, dtype: int64

# %%
Pred_Data['New_pred_result'].value_counts()
# Out:
# H    246
# A     77
# D     57
# Name: New_pred_result, dtype: int64

# %%
Pred_Data['pred_result'].value_counts()
# Out:
# H    172
# D    110
# A     98
# Name: pred_result, dtype: int64

# %% [markdown]
# #  Prediction Using MALA results

# %%
Coef_club1=pd.read_csv('Coef_MALA_Poiss.csv')
Coef_club1=Coef_club1.set_index('Team').sort_index()
Team=Pred_Data.Home.value_counts().index
delta1=Coef_club1['Home_Adv'][0]
classement_mean=pd.DataFrame({'Team':Team})
Sum_Coef_club1=Coef_club1[['Sum_Att','Sum_Dif']]

# %%
mu1, mu2=score_coef(Coef_club1['Sum_Att'],Coef_club1['Sum_Dif'],delta1,Pred_Data)
totpredH_MALA= list()
totpredA_MALA= list()
for i in range(1000):
    home_pred_M = "iter"+str(i)+"home"
    away_pred_M = "iter"+str(i)+"away"
    Pred_Data[home_pred_M]=np.random.poisson(mu1)
    Pred_Data[away_pred_M]=np.random.poisson(mu2)
    totpredH_MALA.append(home_pred_M)
    totpredA_MALA.append(away_pred_M)

avg_home=0
avg_away=0
for i in totpredH_MALA:
    avg_home+=Pred_Data[i]
avg_home=avg_home/len(totpredH_MALA)

for j in totpredA_MALA:
    avg_away+=Pred_Data[j]
avg_away=avg_away/len(totpredA_MALA)

home_goal=(avg_home)
away_goal=(avg_away)

Pred_Data['New_HG_MALA']=home_goal
Pred_Data['New_AG_MALA']=away_goal

pred_result=np.array([])
for i in range (len(Pred_Data)):
    if Pred_Data.iloc[i]['New_HG_MALA']-Pred_Data.iloc[i]['New_AG_MALA']>0.25:
        pred_result=np.concatenate([pred_result,['H']])
    elif Pred_Data.iloc[i]['New_HG_MALA']-Pred_Data.iloc[i]['New_AG_MALA']<0:
        pred_result=np.concatenate([pred_result,['A']])
    else : pred_result=np.concatenate([pred_result,['D']])
Pred_Data['New_pred_result_MALA']=pred_result


diff_score=np.array([])
wrong_res=0
for i in range(379):
    if Pred_Data['Result'][i]==Pred_Data['New_pred_result_MALA'][i]:
        diff_score=np.append(diff_score,0)
    else:
        diff_score=np.append(diff_score,1)
        wrong_res+=1

(380-wrong_res)/380
# Out:
# 0.5026315789473684

# %%
Score=np.array([])
for i in Team :
    s=0
    dom=Pred_Data[Pred_Data.Home==i]
    ext=Pred_Data[Pred_Data.Away==i]
    for j in range(len(dom)):
        if dom.iloc[j]['New_pred_result_MALA']=='H':
                s+=3
        elif dom.iloc[j]['New_pred_result_MALA']=='D':
                s+=1
    for j in range(len(ext)):
        if ext.iloc[j]['New_pred_result_MALA']=='A':
                s+=3
        elif ext.iloc[j]['New_pred_result_MALA']=='D':
                s+=1   
    Score=np.concatenate([Score,[s]])
classement_mean['Classifica']=Score
#classement=classement.set_index('Team')
classement_mean.sort_values(by='Classifica',ascending=False)
# Out:
#           Team  Classifica
# 16       Inter        84.0
# 10       Milan        68.0
# 2         Roma        67.0
# 4      Palermo        57.0
# 6   Fiorentina        56.0
# 8     Juventus        55.0
# 0    Sampdoria        55.0
# 7      Catania        53.0
# 9     Cagliari        53.0
# 11      Napoli        53.0
# 15     Udinese        53.0
# 13     Bologna        52.0
# 5        Lazio        51.0
# 14       Genoa        51.0
# 19        Bari        51.0
# 3        Parma        50.0
# 17    Atalanta        50.0
# 18       Siena        50.0
# 1       Chievo        49.0
# 12     Livorno        46.0

# %%
Pred_Data['Result'].value_counts()
# Out:
# H    186
# D    102
# A     92
# Name: Result, dtype: int64

# %%
Pred_Data['New_pred_result_MALA'].value_counts()
# Out:
# H    339
# D     36
# A      5
# Name: New_pred_result_MALA, dtype: int64

# %%
prob=pd.DataFrame({'Team':Team})
prob=prob.set_index('Team').sort_index()

#Create Matrix containing all the probabilities
proba_tot=[]
for i in range(len(Sum_Coef_club1)):
    A=Sum_Coef_club1.iloc[i]
    proba_A=[]
    for j in range(len(Sum_Coef_club1)):
        if j !=i:
            B=Sum_Coef_club1.iloc[j]
            proba_A.append(probawin(A,B))
        if j==i:
            proba_A.append(0)
    proba_tot.append(proba_A)
XA=Team.sort_values()
j=0
for i in XA:
    prob[i]=np.transpose(proba_tot)[j]
    j+=1  
prob.style.background_gradient(
    cmap = sns.palettes.diverging_palette(h_neg=0, h_pos=243, s=75, l=40,
                                          as_cmap=True)).to_excel("proba_MALA.xlsx")

# %% [markdown]
# # Prediction Using Gradient Descent Method

# %%
Coef_club2=pd.read_csv('Coef_Gradient_Descent.csv')
Coef_club2=Coef_club2.set_index('Team').sort_index()
Team=Pred_Data.Home.value_counts().index
delta2=Coef_club2['Home_Adv'][0]
classement_mean=pd.DataFrame({'Team':Team})
Coef_club2=Coef_club2[['Pred_Att', 'Pred_Dif']]

# %%
mu1, mu2=score_coef(Coef_club2['Pred_Att'],Coef_club2['Pred_Dif'],delta2,Pred_Data)
totpredH_Grad= list()
totpredA_Grad= list()
for i in range(1000):
    home_pred_G = "iter"+str(i)+"home"
    away_pred_G = "iter"+str(i)+"away"
    Pred_Data[home_pred_G]=np.random.poisson(mu1)
    Pred_Data[away_pred_G]=np.random.poisson(mu2)
    totpredH_Grad.append(home_pred_G)
    totpredA_Grad.append(away_pred_G)

avg_home=0
avg_away=0
for i in totpredH_Grad:
    avg_home+=Pred_Data[i]
avg_home=avg_home/len(totpredH_Grad)

for j in totpredA_Grad:
    avg_away+=Pred_Data[j]
avg_away=avg_away/len(totpredA_Grad)

home_goal=(avg_home)
away_goal=(avg_away)

Pred_Data['New_HG_Grad']=home_goal
Pred_Data['New_AG_Grad']=away_goal

pred_result=np.array([])
for i in range (len(Pred_Data)):
    if Pred_Data.iloc[i]['New_HG_Grad']-Pred_Data.iloc[i]['New_AG_Grad']>0.25:
        pred_result=np.concatenate([pred_result,['H']])
    elif Pred_Data.iloc[i]['New_HG_Grad']-Pred_Data.iloc[i]['New_AG_Grad']<0:
        pred_result=np.concatenate([pred_result,['A']])
    else : pred_result=np.concatenate([pred_result,['D']])
Pred_Data['New_pred_result_Grad']=pred_result


diff_score=np.array([])
wrong_res=0
for i in range(379):
    if Pred_Data['Result'][i]==Pred_Data['New_pred_result_Grad'][i]:
        diff_score=np.append(diff_score,0)
    else:
        diff_score=np.append(diff_score,1)
        wrong_res+=1

(380-wrong_res)/380
# Out:
# 0.5078947368421053

# %%
Score=np.array([])
for i in Team :
    s=0
    dom=Pred_Data[Pred_Data.Home==i]
    ext=Pred_Data[Pred_Data.Away==i]
    for j in range(len(dom)):
        if dom.iloc[j]['New_pred_result_Grad']=='H':
                s+=3
        elif dom.iloc[j]['New_pred_result_Grad']=='D':
                s+=1
    for j in range(len(ext)):
        if ext.iloc[j]['New_pred_result_Grad']=='A':
                s+=3
        elif ext.iloc[j]['New_pred_result_Grad']=='D':
                s+=1   
    Score=np.concatenate([Score,[s]])
classement_mean['Classifica']=Score
#classement=classement.set_index('Team')
classement_mean.sort_values(by='Classifica',ascending=False)
# Out:
#           Team  Classifica
# 16       Inter       108.0
# 2         Roma        99.0
# 10       Milan        97.0
# 8     Juventus        88.0
# 6   Fiorentina        74.0
# 4      Palermo        60.0
# 15     Udinese        56.0
# 11      Napoli        54.0
# 14       Genoa        51.0
# 0    Sampdoria        51.0
# 5        Lazio        51.0
# 19        Bari        50.0
# 17    Atalanta        47.0
# 9     Cagliari        43.0
# 1       Chievo        35.0
# 7      Catania        31.0
# 13     Bologna        29.0
# 18       Siena        25.0
# 3        Parma        22.0
# 12     Livorno         5.0

# %%
prob=pd.DataFrame({'Team':Team})
prob=prob.set_index('Team').sort_index()

#Create Matrix containing all the probabilities
proba_tot=[]
for i in range(len(Coef_club2)):
    A=Coef_club2.iloc[i]
    proba_A=[]
    for j in range(len(Coef_club2)):
        if j !=i:
            B=Sum_Coef_club1.iloc[j]
            proba_A.append(probawin(A,B))
        if j==i:
            proba_A.append(0)
    proba_tot.append(proba_A)
XA=Team.sort_values()
j=0
for i in XA:
    prob[i]=np.transpose(proba_tot)[j]
    j+=1  
prob.style.background_gradient(
    cmap = sns.palettes.diverging_palette(h_neg=0, h_pos=243, s=75, l=40,
                                          as_cmap=True)).to_excel("prob_Gradient.xlsx")

# %%
Pred_Data['Result'].value_counts()
# Out:
# H    186
# D    102
# A     92
# Name: Result, dtype: int64

# %%
Pred_Data['New_pred_result_Grad'].value_counts()
# Out:
# H    248
# A     68
# D     64
# Name: New_pred_result_Grad, dtype: int64

# %%
delta2
# Out:
# 0.3917771531211016

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
from scipy.stats import skellam
import seaborn as sns
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
Pred_Data=pd.read_csv("../Data/2009-2010.csv")
Pred_Data=Pred_Data[['HomeTeam','AwayTeam','FTHG','FTAG','FTR']]
Pred_Data.columns=['Home','Away','HG','AG','Result']
Team=Pred_Data.Home.value_counts().index
Pred_Data['diff_score']=Pred_Data['HG']-Pred_Data['AG']

# %%
len(Pred_Data[Pred_Data['Result']=='H'])/len(Pred_Data)
# Out:
# 0.48947368421052634

# %% [markdown]
# # Useful function for our predictions

# %%
def score_coef(att,dif,delta,Data):
    mu1=np.array([])
    mu2=np.array([])
    for i in range(len(Pred_Data)):
        m1=np.exp(delta+att.loc[Data.loc[i].Home]-dif.loc[Data.loc[i].Away])
        m2=np.exp(att.loc[Data.loc[i].Away]-dif.loc[Data.loc[i].Home])
        mu1=np.append(mu1,m1)
        mu2=np.append(mu2,m2)
    return mu1, mu2

# %%
#Function to calculate the mean for a given match
def calc_score(att_h,dif_h,att_a,dif_a,delta):
    m1=np.exp(delta+att_h-dif_a)
    m2=np.exp(att_a-dif_h)
    return m1, m2

# %%
#Calculate the probability of winning against another team without home coef
def probawin(A,B,k=0):
    mu_h,mu_a=calc_score(A[0],A[1],B[0],B[1],delta=0)
    return 1-skellam.cdf(k,  mu_h,  mu_a)

# %% [markdown]
# # Prediction Using Metropolis within Gibbs results

# %%
Coef_club=pd.read_csv('../Data/Coef_MCMC_Skellam.csv')
Coef_club=Coef_club.set_index('Team').sort_index()
Team=Pred_Data.Home.value_counts().index
delta=Coef_club['Home_adv'][0]
classement_mean=pd.DataFrame({'Team':Team})

# %%
Sum_Coef_club= Coef_club[['Sum_Att','Sum_Dif']]
Sum_Coef_club
# Out:
#              Sum_Att   Sum_Dif
# Team
# Atalanta    0.022639 -0.156036
# Bari        0.188900 -0.196121
# Bologna    -0.075426 -0.217236
# Cagliari   -0.151764  0.015559
# Catania    -0.063157 -0.061736
# Chievo     -0.335091  0.093100
# Fiorentina  0.160275  0.022506
# Genoa       0.011635 -0.082672
# Inter       0.292167  0.683262
# Juventus    0.196484  0.212340
# Lazio      -0.030879 -0.066004
# Livorno    -0.325877 -0.227389
# Milan       0.286934  0.148282
# Napoli      0.014099 -0.030990
# Palermo     0.088534 -0.068440
# Parma      -0.418403 -0.024307
# Roma        0.294877  0.189327
# Sampdoria   0.171265 -0.171611
# Siena      -0.320970 -0.060629
# Udinese    -0.006225 -0.001147

# %%
#Generate the means of the Home and Away teams 
mu1 ,mu2=score_coef(Coef_club['Sum_Att'],Coef_club['Sum_Dif'],delta,Pred_Data)

# %%
#Generate 1000 simulations of Skellam distribution
totdif= list()
for i in range(1000):
    dif_pred = "iter"+str(i)
    Pred_Data[dif_pred]=skellam.rvs(mu1,mu2)
    totdif.append(dif_pred)

avg_dif=0
for i in totdif:
    avg_dif+=Pred_Data[i]
avg_dif=(avg_dif/len(totdif))
Pred_Data['New_pred_diff_score']=avg_dif

pred_result=np.array([])
for i in range (len(Pred_Data)):
    if Pred_Data.iloc[i]['New_pred_diff_score']>0.25:
        pred_result=np.concatenate([pred_result,['H']])
    elif Pred_Data.iloc[i]['New_pred_diff_score']<0:
        pred_result=np.concatenate([pred_result,['A']])
    else : pred_result=np.concatenate([pred_result,['D']])
Pred_Data['New_pred_result']=pred_result

# %%
#Count number of well predicted results
diff_score=np.array([])
wrong_res=0
for i in range(379):
    if Pred_Data['Result'][i]==Pred_Data['New_pred_result'][i]:
        diff_score=np.append(diff_score,0)
    else:
        diff_score=np.append(diff_score,1)
        wrong_res+=1

(380-wrong_res)/380
# Out:
# 0.4921052631578947

# %%
#Create a Ranking with the new results obtained
Score=np.array([])
for i in Team :
    s=0
    dom=Pred_Data[Pred_Data.Home==i]
    ext=Pred_Data[Pred_Data.Away==i]
    for j in range(len(dom)):
        if dom.iloc[j]['New_pred_result']=='H':
                s+=3
        elif dom.iloc[j]['New_pred_result']=='D':
                s+=1
    for j in range(len(ext)):
        if ext.iloc[j]['New_pred_result']=='A':
                s+=3
        elif ext.iloc[j]['New_pred_result']=='D':
                s+=1   
    Score=np.concatenate([Score,[s]])
classement_mean['Classifica']=Score
#classement=classement.set_index('Team')
classement_mean.sort_values(by='Classifica',ascending=False)
# Out:
#           Team  Classifica
# 18       Inter       114.0
# 10        Roma       103.0
# 5     Juventus       100.0
# 3        Milan        98.0
# 16  Fiorentina        78.0
# 0      Palermo        60.0
# 9         Bari        59.0
# 6    Sampdoria        58.0
# 14     Udinese        58.0
# 19      Napoli        58.0
# 4        Genoa        52.0
# 12     Catania        50.0
# 17       Lazio        46.0
# 2     Atalanta        44.0
# 7     Cagliari        35.0
# 1       Chievo        26.0
# 11       Siena        17.0
# 15     Bologna        16.0
# 8        Parma         9.0
# 13     Livorno         4.0

# %%
#Create Matrix with all the odds of beating any other team
proba_tot=[]
for i in range(len(Sum_Coef_club)):
    A=Sum_Coef_club.iloc[i]
    proba_A=[]
    for j in range(len(Sum_Coef_club)):
        if j !=i:
            B=Sum_Coef_club.iloc[j]
            proba_A.append(probawin(A,B))
        if j==i:
            proba_A.append(0)
    proba_tot.append(proba_A)

# %%
prob=pd.DataFrame({'Team':Team})
prob=prob.set_index('Team').sort_index()
ordered=Team.sort_values()
j=0
for i in ordered:
    prob[i]=np.transpose(proba_tot)[j]
    j+=1

# %%
prob.style.background_gradient(
    cmap = sns.palettes.diverging_palette(h_neg=0, h_pos=243, s=75, l=40,
                                          as_cmap=True))
# Out:
# <style  type="text/css" >
#     #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col0 {
#             background-color:  #ab2f53;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col1 {
#             background-color:  #e8eff5;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col2 {
#             background-color:  #cbd9e4;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col3 {
#             background-color:  #d3dfe9;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col4 {
#             background-color:  #d7e2ec;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col5 {
#             background-color:  #c7d5e2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col6 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col7 {
#             background-color:  #dee7ef;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col8 {
#             background-color:  #e7eef5;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col9 {
#             background-color:  #f8e7ec;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col10 {
#             background-color:  #dae5ed;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col11 {
#             background-color:  #b4c7d7;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col12 {
#             background-color:  #f5e1e7;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col13 {
#             background-color:  #e1eaf1;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col14 {
#             background-color:  #e5edf4;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col15 {
#             background-color:  #baccda;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col16 {
#             background-color:  #f4dee4;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col17 {
#             background-color:  #e8eff5;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col18 {
#             background-color:  #c1d1de;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row0_col19 {
#             background-color:  #e1eaf1;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col0 {
#             background-color:  #bccddb;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col1 {
#             background-color:  #ab2f53;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col2 {
#             background-color:  #acc1d2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col3 {
#             background-color:  #b6c8d8;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col4 {
#             background-color:  #b9cad9;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col5 {
#             background-color:  #a8bdcf;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col6 {
#             background-color:  #d7e2ec;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col7 {
#             background-color:  #c1d1de;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col8 {
#             background-color:  #cad7e3;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col9 {
#             background-color:  #e8eff5;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col10 {
#             background-color:  #bccddb;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col11 {
#             background-color:  #96afc5;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col12 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col13 {
#             background-color:  #c4d3e0;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col14 {
#             background-color:  #cad7e3;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col15 {
#             background-color:  #9cb4c8;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col16 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col17 {
#             background-color:  #cbd9e4;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col18 {
#             background-color:  #a1b8cb;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row1_col19 {
#             background-color:  #c4d3e0;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col0 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col1 {
#             background-color:  #f6e4e9;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col2 {
#             background-color:  #ab2f53;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col3 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col4 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col5 {
#             background-color:  #e2ebf2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col6 {
#             background-color:  #f2d9e0;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col7 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col8 {
#             background-color:  #f5dfe5;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col9 {
#             background-color:  #eccbd4;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col10 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col11 {
#             background-color:  #d0dde7;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col12 {
#             background-color:  #e9c3ce;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col13 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col14 {
#             background-color:  #f8e7ec;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col15 {
#             background-color:  #d6e1eb;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col16 {
#             background-color:  #e8c2cd;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col17 {
#             background-color:  #f6e4e9;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col18 {
#             background-color:  #dae5ed;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row2_col19 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col0 {
#             background-color:  #e4ecf3;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col1 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col2 {
#             background-color:  #d7e2ec;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col3 {
#             background-color:  #ab2f53;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col4 {
#             background-color:  #e2ebf2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col5 {
#             background-color:  #d6e1eb;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col6 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col7 {
#             background-color:  #e7eef5;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col8 {
#             background-color:  #e4ecf3;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col9 {
#             background-color:  #f6e4e9;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col10 {
#             background-color:  #e4ecf3;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col11 {
#             background-color:  #c5d4e1;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col12 {
#             background-color:  #f5dfe5;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col13 {
#             background-color:  #eaf0f6;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col14 {
#             background-color:  #f2f2f2;
#         }    #T_0a42f32e_9078_11e9_845d_34e12d888ef6row3_col15 {
#             background-color:  #cbd9e4;
#         }    #T_0a42f32e_9078_11e9_845d_34e

# %%
Pred_Data['Result'].value_counts()
# Out:
# H    186
# D    102
# A     92
# Name: Result, dtype: int64

# %%
Pred_Data['New_pred_result'].value_counts()
# Out:
# H    223
# A    102
# D     55
# Name: New_pred_result, dtype: int64

# %% [markdown]
# #  Prediction Using MALA results

# %%
Coef_club1=pd.read_csv('Coef_MALA.csv')
Coef_club1=Coef_club1.set_index('Team').sort_index()
Team=Pred_Data.Home.value_counts().index
delta1=Coef_club1['Home_Adv'][0]
classement_mean=pd.DataFrame({'Team':Team})
Sum_Coef_club1=Coef_club1[['Sum_Att','Sum_Dif']]

# %%
mu1 ,mu2=score_coef(Coef_club1['Sum_Att'],Coef_club1['Sum_Dif'],delta1,Pred_Data)
totdif_MALA= list()
for i in range(1000):
    dif_pred_MALA = "iter"+str(i)
    Pred_Data[dif_pred_MALA]=skellam.rvs(mu1,mu2)
    totdif_MALA.append(dif_pred_MALA)

avg_dif=0
for i in totdif_MALA:
    avg_dif+=Pred_Data[i]
avg_dif=avg_dif/len(totdif_MALA)
Pred_Data['New_pred_diff_score_MALA']=avg_dif

pred_result1=np.array([])
for i in range (len(Pred_Data)):
    if Pred_Data.iloc[i]['New_pred_diff_score_MALA']>0.25:
        pred_result1=np.concatenate([pred_result1,['H']])
    elif Pred_Data.iloc[i]['New_pred_diff_score_MALA']<0:
        pred_result1=np.concatenate([pred_result1,['A']])
    else : pred_result1=np.concatenate([pred_result1,['D']])
Pred_Data['New_pred_result_MALA']=pred_result1

diff_score=np.array([])
wrong_res=0
for i in range(379):
    if Pred_Data['Result'][i]==Pred_Data['New_pred_result_MALA'][i]:
        diff_score=np.append(diff_score,0)
    else:
        diff_score=np.append(diff_score,1)
        wrong_res+=1

(380-wrong_res)/380
# Out:
# 0.5052631578947369

# %%
Score=np.array([])
for i in Team :
    s=0
    dom=Pred_Data[Pred_Data.Home==i]
    ext=Pred_Data[Pred_Data.Away==i]
    for j in range(len(dom)):
        if dom.iloc[j]['New_pred_result_MALA']=='H':
                s+=3
        elif dom.iloc[j]['New_pred_result_MALA']=='D':
                s+=1
    for j in range(len(ext)):
        if ext.iloc[j]['New_pred_result_MALA']=='A':
                s+=3
        elif ext.iloc[j]['New_pred_result_MALA']=='D':
                s+=1   
    Score=np.concatenate([Score,[s]])
classement_mean['Classifica']=Score
#classement=classement.set_index('Team')
classement_mean.sort_values(by='Classifica',ascending=False)
# Out:
#           Team  Classifica
# 12       Inter        90.0
# 3         Roma        82.0
# 5        Milan        78.0
# 1      Palermo        62.0
# 0     Juventus        60.0
# 10  Fiorentina        59.0
# 6         Bari        57.0
# 4    Sampdoria        56.0
# 2      Udinese        54.0
# 19       Lazio        53.0
# 18    Cagliari        52.0
# 7      Bologna        49.0
# 8       Chievo        49.0
# 16       Genoa        48.0
# 17      Napoli        46.0
# 14    Atalanta        43.0
# 15     Catania        42.0
# 9        Siena        32.0
# 11     Livorno        29.0
# 13       Parma        28.0

# %%
Pred_Data['Result'].value_counts()
# Out:
# H    186
# D    102
# A     92
# Name: Result, dtype: int64

# %%
Pred_Data['New_pred_result_MALA'].value_counts()
# Out:
# H    292
# D     71
# A     17
# Name: New_pred_result_MALA, dtype: int64

# %%
prob=pd.DataFrame({'Team':Team})
prob=prob.set_index('Team').sort_index()

#Create Matrix containing all the probabilities
proba_tot=[]
for i in range(len(Sum_Coef_club1)):
    A=Sum_Coef_club1.iloc[i]
    proba_A=[]
    for j in range(len(Sum_Coef_club1)):
        if j !=i:
            B=Sum_Coef_club1.iloc[j]
            proba_A.append(probawin(A,B))
        if j==i:
            proba_A.append(0)
    proba_tot.append(proba_A)
XA=Team.sort_values()
j=0
for i in XA:
    prob[i]=np.transpose(proba_tot)[j]
    j+=1  
prob.style.background_gradient(
    cmap = sns.palettes.diverging_palette(h_neg=0, h_pos=243, s=75, l=40,
                                          as_cmap=True)).to_excel("proba_MALA_Skellam.xlsx")
